# %%
import mne
import csv
import numpy as np
import os
import random
import math
import os.path as op
import scipy
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
raw001 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub001.set')
raw004 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub004.set')
raw005 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub005.set')
raw006 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub006.set')
raw007 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub007.set')
raw008 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub008.set')
raw009 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub009.set')
raw010 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub010.set')
raw011 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub011.set')
raw012 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub012.set')
raw013 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub013.set')
raw014 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub014.set')
raw015 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub015.set')
raw016 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub016.set')
raw017 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub017.set')
raw018 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub018.set')
raw019 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub019.set')
raw020 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub020.set')
raw021 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub021.set')
raw022 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub022.set')
raw023 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub023.set')
raw024 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub024.set')
raw025 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub025.set')
raw = mne.concatenate_raws([raw001,raw004,raw005,raw006,raw007,raw008,raw009,raw010,raw011,
                            raw012,raw013,raw014,raw015,raw016,raw017,raw018,raw019,raw020,raw021,raw022,raw023,raw024,raw025])

events_info = mne.events_from_annotations(raw)
events = events_info[0]
event_dict = events_info[1]
# reject = dict(eeg=40e-6)
# epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0),reject=reject)
# epochs_w = mne.Epochs(raw, events, event_id=event_dict, tmin=-0.6, tmax=0.0,preload=True, baseline=(0, 0),reject=reject)
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_w = mne.Epochs(raw, events, event_id=event_dict, tmin=-0.6, tmax=0.0,preload=True, baseline=(0, 0))
# Out:
# Reading E:\FreeEnergy-data\eeg_data\zs_sub001.fdt
# Reading E:\FreeEnergy-data\eeg_data\zs_sub004.fdt
# C:\Users\dell\AppData\Local\Temp\ipykernel_11764\702159959.py:1: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw001 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub001.set')
# C:\Users\dell\AppData\Local\Temp\ipykernel_11764\702159959.py:1: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw001 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub001.set')
# Reading E:\FreeEnergy-data\eeg_data\zs_sub005.fdt
# C:\Users\dell\AppData\Local\Temp\ipykernel_11764\702159959.py:2: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   raw004 = mne.io.read_raw_eeglab('E:/FreeEnergy-data/eeg_data/zs_sub004.set')
# ...

# %%
second_drop_first_half = [0]
second_drop_second_half = [0]
num_trial = -1
for i in range(len(epochs)-1):
    if (list(epochs[i].event_id.keys())) in [['0001'],['0002']]:
        num_trial += 1
        num_trial = num_trial % 120        
    if (list(epochs[i].event_id.keys())) in [['0003'],['0005'],['0004']]:
        if num_trial % 120 < 60:
            second_drop_second_half.append(i+1) 
        else:
            second_drop_first_half.append(i+1)
    else:
        second_drop_second_half.append(i+1) 
        second_drop_first_half.append(i+1)

# %%
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
second_choice_first_half = epochs.drop(second_drop_first_half)
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
second_choice_second_half = epochs.drop(second_drop_second_half )

second_choice_first_half_evoked = second_choice_first_half.average()
second_choice_second_half_evoked = second_choice_second_half.average()

epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_left = epochs.pick_channels(['E34','E27','E23','E18','E28','E24','E19','E29','E20','E12','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_right = epochs.pick_channels(['E10','E3','E123','E116','E4','E124','E117','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_central = epochs.pick_channels(['E30','E13','E6','E112','E105','E31','E7','E106','E80','E55'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_left = epochs.pick_channels(['E51','E59','E47','E52','E60','E67','E42','E53','E61','E37','E54',])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_right = epochs.pick_channels(['E91','E97','E77','E85','E92','E98','E78','E86','E93','E79','E87'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))

second_choice_first_half_frontal_left = epochs_frontal_left.drop(second_drop_first_half)
second_choice_first_half_frontal_right = epochs_frontal_right.drop(second_drop_first_half)
second_choice_first_half_central = epochs_central.drop(second_drop_first_half)
second_choice_first_half_parietal_left = epochs_parietal_left.drop(second_drop_first_half)
second_choice_first_half_parietal_right = epochs_parietal_right.drop(second_drop_first_half)

epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_left = epochs.pick_channels(['E34','E27','E23','E18','E28','E24','E19','E29','E20','E12','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_right = epochs.pick_channels(['E10','E3','E123','E116','E4','E124','E117','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_central = epochs.pick_channels(['E30','E13','E6','E112','E105','E31','E7','E106','E80','E55'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_left = epochs.pick_channels(['E51','E59','E47','E52','E60','E67','E42','E53','E61','E37','E54',])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_right = epochs.pick_channels(['E91','E97','E77','E85','E92','E98','E78','E86','E93','E79','E87'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))

second_choice_second_half_frontal_left = epochs_frontal_left.drop(second_drop_second_half)
second_choice_second_half_frontal_right = epochs_frontal_right.drop(second_drop_second_half)
second_choice_second_half_central = epochs_central.drop(second_drop_second_half)
second_choice_second_half_parietal_left = epochs_parietal_left.drop(second_drop_second_half)
second_choice_second_half_parietal_right = epochs_parietal_right.drop(second_drop_second_half)
# Out:
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped
# ...

# %%
second_choice_first_half_frontal_left_data = np.average(second_choice_first_half_frontal_left.get_data(),axis=(1,2)).squeeze()
second_choice_first_half_frontal_right_data = np.average(second_choice_first_half_frontal_right.get_data(),axis=(1,2)).squeeze()
second_choice_first_half_central_data = np.average(second_choice_first_half_central.get_data(),axis=(1,2)).squeeze()
second_choice_first_half_parietal_left_data = np.average(second_choice_first_half_parietal_left.get_data(),axis=(1,2)).squeeze()
second_choice_first_half_parietal_right_data = np.average(second_choice_first_half_parietal_right.get_data(),axis=(1,2)).squeeze()

second_choice_second_half_frontal_left_data = np.average(second_choice_second_half_frontal_left.get_data(),axis=(1,2)).squeeze()
second_choice_second_half_frontal_right_data = np.average(second_choice_second_half_frontal_right.get_data(),axis=(1,2)).squeeze()
second_choice_second_half_central_data = np.average(second_choice_second_half_central.get_data(),axis=(1,2)).squeeze()
second_choice_second_half_parietal_left_data = np.average(second_choice_second_half_parietal_left.get_data(),axis=(1,2)).squeeze()
second_choice_second_half_parietal_right_data = np.average(second_choice_second_half_parietal_right.get_data(),axis=(1,2)).squeeze()

# %%
amplitude = np.concatenate((second_choice_first_half_frontal_left_data,second_choice_first_half_frontal_right_data,second_choice_first_half_central_data,
                            second_choice_first_half_parietal_left_data,second_choice_first_half_parietal_right_data,
                            second_choice_second_half_frontal_left_data,second_choice_second_half_frontal_right_data,second_choice_second_half_central_data,
                            second_choice_second_half_parietal_left_data,second_choice_second_half_parietal_right_data))
condition = []
for i in range(1380*5):
    condition.append('first_half')
for i in range(1380*5):
    condition.append('second_half')
position = []
for i in range(1380):
    position.append('frontal_left')
for i in range(1380):
    position.append('frontal_right')
for i in range(1380):
    position.append('central')
for i in range(1380):
    position.append('parietal_left')
for i in range(1380):
    position.append('parietal_right')
for i in range(1380):
    position.append('frontal_left')
for i in range(1380):
    position.append('frontal_right')
for i in range(1380):
    position.append('central')
for i in range(1380):
    position.append('parietal_left')
for i in range(1380):
    position.append('parietal_right')
data = {'amplitude':amplitude,
        'condition':condition,
        'position':position}
data = pd.DataFrame(data)

# %%
ax = sns.barplot(x="position", 
        y="amplitude", 
        hue="condition", 
        palette=[(254/255,129/255,125/255),(129/255,184/255,223/255)],
        data=data)
plt.text(0,1.5*10**(-6),'**',horizontalalignment="center")
plt.text(1,1.5*10**(-6),'*',horizontalalignment="center")
plt.text(2,1.5*10**(-6),'**',horizontalalignment="center")
plt.text(3,2.8*10**(-6),'*',horizontalalignment="center")
plt.show()

# %%
_,p_frontal_left = stats.ttest_ind(second_choice_first_half_frontal_left_data,second_choice_second_half_frontal_left_data)
print(p_frontal_left)
_,p_frontal_right = stats.ttest_ind(second_choice_first_half_frontal_right_data,second_choice_second_half_frontal_right_data)
print(p_frontal_right)
_,p_central = stats.ttest_ind(second_choice_first_half_central_data,second_choice_second_half_central_data)
print(p_central)
_,p_parietal_left = stats.ttest_ind(second_choice_first_half_parietal_left_data,second_choice_second_half_parietal_left_data)
print(p_parietal_left)
_,p_parietal_right = stats.ttest_ind(second_choice_first_half_parietal_right_data,second_choice_second_half_parietal_right_data)
print(p_parietal_right)
# Out:
# 0.002353313550768287
# 0.04264455154205981
# 0.0012860150696564797
# 0.03155545250163089
# 0.6034616505263481

# %%
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
second_choice_first_half = epochs.drop(second_drop_first_half)
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
second_choice_second_half = epochs.drop(second_drop_second_half)

second_choice_first_half_evoked = second_choice_first_half.average()
second_choice_second_half_evoked = second_choice_second_half.average()
# Out:
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped
# ...

# %%
times = np.linspace(0.15, 1.95, 9)
fig = second_choice_first_half_evoked.plot_topomap(times=times,average=0.2,vmin=-9,vmax=9)
fig = second_choice_second_half_evoked.plot_topomap(times=times,average=0.2,vmin=-9,vmax=9)
# Out:
# <MNEFigure size 1080x158.4 with 10 Axes>
# <MNEFigure size 1080x158.4 with 10 Axes>

# %%
def convert_pvalue_to_asterisks(pvalue):
    if pvalue <= 0.0001:
        return "****"
    elif pvalue <= 0.001:
        return "***"
    elif pvalue <= 0.01:
        return "**"
    elif pvalue <= 0.05:
        return "*"
    return "ns"
_,p_frontal_left = stats.ttest_ind(second_choice_first_half_frontal_left_data,second_choice_second_half_frontal_left_data)
print(p_frontal_left)
# Out:
# 0.002353313550768287

# %%
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
second_ask_drop = [0]
second_no_drop = [0]
for i in range(len(epochs)-1):
    if not (list(epochs[i].event_id.keys())) in [['0003'],['0005']]:
        second_ask_drop.append(i+1) 
    if not (list(epochs[i].event_id.keys())) in [['0004']]:
        second_no_drop.append(i+1)
# Out:
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped

# %%
print(len(second_ask_drop))
print(len(second_no_drop))
print(len(epochs))
# Out:
# 11711
# 11787
# 13129

# %%
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_left = epochs.pick_channels(['E34','E27','E23','E18','E28','E24','E19','E29','E20','E12','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_right = epochs.pick_channels(['E10','E3','E123','E116','E4','E124','E117','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_central = epochs.pick_channels(['E30','E13','E6','E112','E105','E31','E7','E106','E80','E55'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_left = epochs.pick_channels(['E51','E59','E47','E52','E60','E67','E42','E53','E61','E37','E54',])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_right = epochs.pick_channels(['E91','E97','E77','E85','E92','E98','E78','E86','E93','E79','E87'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))


second_choice_ask_frontal_left = epochs_frontal_left.drop(second_ask_drop)
second_choice_ask_frontal_right = epochs_frontal_right.drop(second_ask_drop)
second_choice_ask_central = epochs_central.drop(second_ask_drop)
second_choice_ask_parietal_left = epochs_parietal_left.drop(second_ask_drop)
second_choice_ask_parietal_right = epochs_parietal_right.drop(second_ask_drop)

epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_left = epochs.pick_channels(['E34','E27','E23','E18','E28','E24','E19','E29','E20','E12','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_frontal_right = epochs.pick_channels(['E10','E3','E123','E116','E4','E124','E117','E5','E118','E111'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_central = epochs.pick_channels(['E30','E13','E6','E112','E105','E31','E7','E106','E80','E55'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_left = epochs.pick_channels(['E51','E59','E47','E52','E60','E67','E42','E53','E61','E37','E54',])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
epochs_parietal_right = epochs.pick_channels(['E91','E97','E77','E85','E92','E98','E78','E86','E93','E79','E87'])
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))

second_choice_no_frontal_left = epochs_frontal_left.drop(second_no_drop)
second_choice_no_frontal_right = epochs_frontal_right.drop(second_no_drop)
second_choice_no_central = epochs_central.drop(second_no_drop)
second_choice_no_parietal_left = epochs_parietal_left.drop(second_no_drop)
second_choice_no_parietal_right = epochs_parietal_right.drop(second_no_drop)
# Out:
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# ...

# %%
second_choice_ask_frontal_left_data = np.average(second_choice_ask_frontal_left.get_data(),axis=(1,2)).squeeze()
second_choice_ask_frontal_right_data = np.average(second_choice_ask_frontal_right.get_data(),axis=(1,2)).squeeze()
second_choice_ask_central_data = np.average(second_choice_ask_central.get_data(),axis=(1,2)).squeeze()
second_choice_ask_parietal_left_data = np.average(second_choice_ask_parietal_left.get_data(),axis=(1,2)).squeeze()
second_choice_ask_parietal_right_data = np.average(second_choice_ask_parietal_right.get_data(),axis=(1,2)).squeeze()

second_choice_no_frontal_left_data = np.average(second_choice_no_frontal_left.get_data(),axis=(1,2)).squeeze()
second_choice_no_frontal_right_data = np.average(second_choice_no_frontal_right.get_data(),axis=(1,2)).squeeze()
second_choice_no_central_data = np.average(second_choice_no_central.get_data(),axis=(1,2)).squeeze()
second_choice_no_parietal_left_data = np.average(second_choice_no_parietal_left.get_data(),axis=(1,2)).squeeze()
second_choice_no_parietal_right_data = np.average(second_choice_no_parietal_right.get_data(),axis=(1,2)).squeeze()

# %%
amplitude = np.concatenate((second_choice_ask_frontal_left_data,second_choice_ask_frontal_right_data,second_choice_ask_central_data,second_choice_ask_parietal_left_data,second_choice_ask_parietal_right_data,
                      second_choice_no_frontal_left_data,second_choice_no_frontal_right_data,second_choice_no_central_data,second_choice_no_parietal_left_data,second_choice_no_parietal_right_data)).squeeze()
condition = []
for i in range(1418*5):
    condition.append('ask')
for i in range(1342*5):
    condition.append('no')
position = []
for i in range(1418):
    position.append('frontal_left')
for i in range(1418):
    position.append('frontal_right')
for i in range(1418):
    position.append('central')
for i in range(1418):
    position.append('parietal_left')
for i in range(1418):
    position.append('parietal_right')
for i in range(1342):
    position.append('frontal_left')
for i in range(1342):
    position.append('frontal_right')
for i in range(1342):
    position.append('central')
for i in range(1342):
    position.append('parietal_left')
for i in range(1342):
    position.append('parietal_right')
data = {'amplitude':amplitude,
        'condition':condition,
        'position':position}
data = pd.DataFrame(data)

# %%
ax = sns.barplot(x="position", 
        y="amplitude", 
        hue="condition", 
        palette=[(254/255,129/255,125/255),(129/255,184/255,223/255)],
        data=data)
plt.text(0,1.5*10**(-6),'**',horizontalalignment="center")
plt.text(1,1.5*10**(-6),'*',horizontalalignment="center")
plt.text(2,1.5*10**(-6),'***',horizontalalignment="center")
# plt.text(3,4.2*10**(-6),'***',horizontalalignment="center")
# plt.text(4,4.2*10**(-6),'***',horizontalalignment="center")
plt.show()

# %%
_,p_frontal_left = stats.ttest_ind(second_choice_ask_frontal_left_data,second_choice_no_frontal_left_data)
print(p_frontal_left)
_,p_frontal_right = stats.ttest_ind(second_choice_ask_frontal_right_data,second_choice_no_frontal_right_data)
print(p_frontal_right)
_,p_central = stats.ttest_ind(second_choice_ask_central_data,second_choice_no_central_data)
print(p_central)
_,p_parietal_left = stats.ttest_ind(second_choice_ask_parietal_left_data,second_choice_no_parietal_left_data)
print(p_parietal_left)
_,p_parietal_right = stats.ttest_ind(second_choice_ask_parietal_right_data,second_choice_no_parietal_right_data)
print(p_parietal_right)
# Out:
# 0.002238273825730918
# 0.017411089165158145
# 0.0005104281774338599
# 0.3816593894930591
# 0.4835502898161438

# %%
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
second_choice_ask = epochs.drop(second_ask_drop)
epochs = mne.Epochs(raw, events, event_id=event_dict, tmin=0.0, tmax=2.0,preload=True, baseline=(0, 0))
second_choice_no = epochs.drop(second_no_drop)

second_choice_ask_evoked = second_choice_ask.average()
second_choice_no_evoked = second_choice_no.average()
# Out:
# Not setting metadata
# Not setting metadata
# 13129 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Loading data for 13129 events and 501 original time points ...
# 0 bad epochs dropped
# ...

# %%
times = np.linspace(0.15, 1.95, 9)
fig = second_choice_ask_evoked.plot_topomap(times=times,average=0.1,vmin=-9,vmax=9)
fig = second_choice_no_evoked.plot_topomap(times=times,average=0.2,vmin=-9,vmax=9)
# Out:
# <MNEFigure size 1080x158.4 with 10 Axes>
# <MNEFigure size 1080x158.4 with 10 Axes>

# %%
second_choice_first_half.plot_psd_topomap(vlim=(20,46))
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(library.__version__) < LooseVersion(min_version):
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(library.__version__) < LooseVersion(min_version):
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(library.__version__) < LooseVersion(min_version):
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# ...

# %%
second_choice_second_half.plot_psd_topomap(vlim=(20,46))
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(library.__version__) < LooseVersion(min_version):
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(library.__version__) < LooseVersion(min_version):
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(library.__version__) < LooseVersion(min_version):
# c:\ProgramData\Anaconda3\envs\MNE\lib\site-packages\mne\utils\check.py:92: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# ...

# %%
spectrum_first_half =  second_choice_first_half.compute_psd(fmin=1,fmax=30)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# e:\FreeEnergy-data\sensor_level_0.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/FreeEnergy-data/sensor_level_0.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> spectrum_first_half =  second_choice_first_half.compute_psd(fmin=1,fmax=30)
#
# AttributeError: 'Epochs' object has no attribute 'compute_psd'

# %%
mne.__version__
# Out:
# '0.24.1'
